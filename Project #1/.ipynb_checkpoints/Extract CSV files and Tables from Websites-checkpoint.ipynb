# %% [markdown]
# # Project #1 Table Extraction - Extract Tables from Websites
#  Target Website: https://learn.microsoft.com/en-us/training/modules/configure-azure-active-directory/2-describe-benefits-features

# %%
import pandas as pd

# %%
Azure = pd.read_html('https://learn.microsoft.com/en-us/training/modules/configure-azure-active-directory/2-describe-benefits-features')

# %%
len(Azure)
# Out:
# 1

# %%
Azure[0]
# Out:
#               Azure AD feature  \
# 0  Single sign-on (SSO) access
# 1    Ubiquitous device support
# 2         Secure remote access
# 3          Cloud extensibility
# 4    Sensitive data protection
# 5         Self-service support
#
#                                          Description
# 0  Microsoft Entra ID provides secure single sign...
# 1  Microsoft Entra ID works with iOS, macOS, Andr...
# 2  Microsoft Entra ID enables secure remote acces...
# 3  Microsoft Entra ID can extend to the cloud to ...
# 4  Microsoft Entra ID offers unique identity prot...
# 5  Microsoft Entra ID lets you delegate selected ...

# %% [markdown]
# # Read a .csv from a URL with Pandas
#
#   Target Website : https://catalog.data.gov/dataset/alzheimers-disease-and-healthy-aging-data

# %%
# reading 1 csv file from the website

df_CSV = pd.read_csv('https://data.cdc.gov/api/views/hfr9-rurv/rows.csv')

# %%
df_CSV
# Out:
#                                           RowId  YearStart  YearEnd  \
# 0         BRFSS~2022~2022~42~Q03~TMC01~AGE~RACE       2022     2022
# 1         BRFSS~2022~2022~46~Q03~TMC01~AGE~RACE       2022     2022
# 2         BRFSS~2022~2022~16~Q03~TMC01~AGE~RACE       2022     2022
# 3         BRFSS~2022~2022~24~Q03~TMC01~AGE~RACE       2022     2022
# 4       BRFSS~2022~2022~55~Q03~TMC01~AGE~GENDER       2022     2022
# ...                                         ...        ...      ...
# 284137    BRFSS~2016~2016~55~Q15~TSC02~AGE~RACE       2016     2016
# 284138    BRFSS~2017~2017~56~Q45~TOC13~AGE~RACE       2017     2017
# 284139    BRFSS~2015~2015~56~Q42~TCC04~AGE~RACE       2015     2015
# 284140    BRFSS~2019~2019~54~Q46~TOC10~AGE~RACE       2019     2019
# 284141    BRFSS~2015~2015~56~Q02~TNC02~AGE~RACE       2015     2015
#
#        LocationAbbr   LocationDesc Datasource  \
# 0                PA   Pennsylvania      BRFSS
# 1                SD   South Dakota      BRFSS
# ...

# %%
# rename part of the column

df_CSV.rename(columns={'LocationDesc' : 'Location',
                       'LocationAbbr' : 'LAcronym'}, inplace=True)

# %%
df_CSV
# Out:
#                                           RowId  YearStart  YearEnd LAcronym  \
# 0         BRFSS~2022~2022~42~Q03~TMC01~AGE~RACE       2022     2022       PA
# 1         BRFSS~2022~2022~46~Q03~TMC01~AGE~RACE       2022     2022       SD
# 2         BRFSS~2022~2022~16~Q03~TMC01~AGE~RACE       2022     2022       ID
# 3         BRFSS~2022~2022~24~Q03~TMC01~AGE~RACE       2022     2022       MD
# 4       BRFSS~2022~2022~55~Q03~TMC01~AGE~GENDER       2022     2022       WI
# ...                                         ...        ...      ...      ...
# 284137    BRFSS~2016~2016~55~Q15~TSC02~AGE~RACE       2016     2016       WI
# 284138    BRFSS~2017~2017~56~Q45~TOC13~AGE~RACE       2017     2017       WY
# 284139    BRFSS~2015~2015~56~Q42~TCC04~AGE~RACE       2015     2015       WY
# 284140    BRFSS~2019~2019~54~Q46~TOC10~AGE~RACE       2019     2019       WV
# 284141    BRFSS~2015~2015~56~Q02~TNC02~AGE~RACE       2015     2015       WY
#
# ...
